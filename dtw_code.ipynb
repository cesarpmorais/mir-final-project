# %% [markdown]
# #1. Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import librosa
import librosa.display
import os
import pandas as pd
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean

# Diretórios contendo as músicas originais e seus covers
dir_originals = '/content/drive/MyDrive/Trabalhos UFMG/MIR/Beatles dataset (MIR)/beatles_songs_stft'
dir_covers = '/content/drive/MyDrive/Trabalhos UFMG/MIR/Beatles dataset (MIR)/beatles_covers_stft'

# %% [markdown]
# #2. DTW

# %% [markdown]
# ##2.0 Verificando as dimensões dos arquivos
# Importante para a aplicação do DTW (colunas devem ter a mesma dimensão, mas o tempo pode variar).

# %%
for f, arr in originals.items():
    print(f, arr.shape)

for f, arr in covers.items():
    print(f, arr.shape)
# Out:
# 07 The Beatles - This Boy.flac.npy (1025, 1276)
# 07 The Beatles - She Said She Said.flac.npy (1025, 1284)
# 08 The Beatles - Roll Over Beethoven.flac.npy (1025, 1277)
# 08 The Beatles - Revolution.flac.npy (1025, 1276)
# 08 The Beatles - Love Me Do.flac.npy (1025, 1277)
# 08 The Beatles - Komm, Gib Mir Deine Hand.flac.npy (1025, 1278)
# 08 The Beatles - Good Day Sunshine.flac.npy (1025, 1280)
# 08 The Beatles - Eight Days A Week.flac.npy (1025, 1276)
# 08 The Beatles - Any Time At All.flac.npy (1025, 1284)
# 08 The Beatles - Act Naturally.flac.npy (1025, 1280)
# 07 The Beatles - Ticket To Ride.flac.npy (1025, 1284)
# 09 The Beatles - Girl.flac.npy (1025, 1284)
# 09 The Beatles - And Your Bird Can Sing.flac.npy (1025, 1288)
# 08 The Beatles - Within You, Without You.flac.npy (1025, 1213)
# 08 The Beatles - What Goes On.flac.npy (1025, 1276)
# 08 The Beatles - Strawberry Fields Forever.flac.npy (1025, 1269)
# 09 The Beatles - Penny Lane.flac.npy (1025, 1266)
# 09 The Beatles - P.S  I Love You.flac.npy (1025, 1276)
# 09 The Beatles - Only A Northern Song.flac.npy (1025, 1274)
# 09 The Beatles - I_ll Cry Instead.flac.npy (1025, 1284)
# 09 The Beatles - It_s Only Love.flac.npy (1025, 1277)
# 09 The Beatles - Hold Me Tight.flac.npy (1025, 1275)
# 10 The Beatles - Baby It_s You.flac.npy (1025, 1277)
# 10 The Beatles - All Together Now.flac.npy (1025, 1275)
# 09 The Beatles - Words Of Love.flac.npy (1025, 1285)
# 09 The Beatles - When I_m Sixty-Four.flac.npy (1025, 1291)
# 09 The Beatles - Sie Leibt Dich.flac.npy (1025, 1275)
# 10 The Beatles - Lovely Rita.flac.npy (1025, 1283)
# 10 The Beatles - Long Tall Sally.flac.npy (1025, 1276)
# 10 The Beatles - I_m Looking Throuh You.flac.npy (1025, 1281)
# 10 The Beatles - Honey Don_t.flac.npy (1025, 1285)
# 10 The Beatles - For No One.flac.npy (1025, 1284)
# 10 The Beatles - Baby You_re A Rich Man.flac.npy (1025, 1285)
# 11 The Beatles - Doctor Robert.flac.npy (1025, 1283)
# 11 The Beatles - Do You Want To Know A Secret.flac.npy (1025, 1275)
# 11 The Beatles - All You Need Is Love.flac.npy (1025, 1282)
# 10 The Beatles - You Really Got A Hold On Me.flac.npy (1025, 1276)
# 10 The Beatles - You Like Me Too Much.flac.npy (1025, 1283)
# 10 The Beatles - Things We Said Today.flac.npy (1025, 1284)
# 11 The Beatles - Tell Me What You See.flac.npy (1025, 1282)
# 11 The Beatles - In My Life.flac.npy (1025, 1284)
# 11 The Beatles - I Wanna Be Your Man.flac.npy (1025, 1277)
# 11 The Beatles - I Call Your Name.flac.npy (1025, 1275)
# 11 The Beatles - Good Morning, Good Morning.flac.npy (1025, 1284)
# 11 The Beatles - Every Little Thing.flac.npy (1025, 1284)
# 12 The Beatles - It_s All Too Much.flac.npy (1025, 1270)
# 12 The Beatles - I Want To Tell You.flac.npy (1025, 1207)
# 12 The Beatles - I Don_t Want To Spoil The Party.flac.npy (1025, 1285)
# 12 The Beatles - Devil in Her Heart.flac.npy (1025, 1274)
# 12 The Beatles - A Taste Of Honey.flac.npy (1025, 1278)
# 11 The Beatles - When I Get Home.flac.npy (1025, 1285)
# 13 The Beatles (With Billy Preston) - Get Back.flac.npy (1025, 1270)
# 12 The Beatles - You Can_t Do That.flac.npy (1025, 1284)
# 12 The Beatles - Wait.flac.npy (1025, 1280)
# 12 The Beatles - Slow Down.flac.npy (1025, 1271)
# 12 The Beatles - Sgt. Pepper_s Lonely Hearts Club Band (Reprise).flac.npy (1025, 1292)
# 12 The Beatles - I_ve Just Seen A Face.flac.npy (1025, 1277)
# 13 The Beatles - Matchbox.flac.npy (1025, 1275)
# 13 The Beatles - I_ll Be Back.flac.npy (1025, 1284)
# 13 The Beatles - If I Needed Someone.flac.npy (1025, 1284)
# 13 The Beatles - Got To Get You Into My Life.flac.npy (1025, 1284)
# 13 The Beatles - A Day In The Life.flac.npy (1025, 1292)
# 14 The Beatles - Everybody_s Trying To Be My Baby.flac.npy (1025, 1280)
# 14 The Beatles - Dizzy Miss Lizzy.flac.npy (1025, 1284)
# 14 The Beatles (With Billy Preston) - Don_t Let Me Down.flac.npy (1025, 1277)
# 13 The Beatles - Yesterday.flac.npy (1025, 1273)
# 13 The Beatles - What You_re Doing.flac.npy (1025, 1284)
# 13 The Beatles - Not A Second Time.flac.npy (1025, 1277)
# 15 The Beatles - Across The Universe.flac.npy (1025, 1231)
# 14 The Beatles - Twist And Shout.flac.npy (1025, 1277)
# 14 The Beatles - Tomorrow Never Knows.flac.npy (1025, 1270)
# 14 The Beatles - Run For Your Life.flac.npy (1025, 1283)
# 14 The Beatles - Money.flac.npy (1025, 1275)
# 14 The Beatles - I Feel Fine.flac.npy (1025, 1271)
# All Together Now (Remastered 2009) [73lj5qJbrms].mp4.npy (1025, 1273)
# Across The Universe (Remastered 2009) [90M60PzmxEE].mp4.npy (1025, 1274)
# 18 The Beatles - I_m Down.flac.npy (1025, 1273)
# 17 The Beatles - Yes It Is.flac.npy (1025, 1273)
# 16 The Beatles - Bad Boy.flac.npy (1025, 1277)
# 15 The Beatles - She_s a Woman.flac.npy (1025, 1278)
# Carry That Weight (Remastered 2009) [6B224XDJw6g].mp4.npy (1025, 1289)
# Blackbird (Remastered 2009) [Man4Xw8Xypo].mp4.npy (1025, 1285)
# Birthday (Remastered 2009) [dhdOPhTHeoE].mp4.npy (1025, 1245)
# Because (Remastered 2009) [hL0tnrl2L_U].mp4.npy (1025, 1271)
# Back In The U.S.S.R. (Remastered 2009) [0ArlUSVDQIw].mp4.npy (1025, 1091)
# All You Need Is Love (Remastered 2009) [_7xMfIp-irg].mp4.npy (1025, 1273)
# Don't Pass Me By (Remastered 2009) [PTKEiQHHsuk].mp4.npy (1025, 1286)
# Dig It (Remastered 2009) [fUUOX6kAIxI].mp4.npy (1025, 1163)
# Dig A Pony (Remastered 2009) [LpdJE7HG8Ls].mp4.npy (1025, 1128)
# Dear Prudence (Remastered 2009) [wQA59IkCF5I].mp4.npy (1025, 1289)
# Cry Baby Cry (Remastered 2009) [8Zeyej5bfZE].mp4.npy (1025, 1273)
# Come Together (Remastered 2009) [oolpPmuK2I8].mp4.npy (1025, 1245)
# Good Night (Remastered 2009) [Qp_djIuQ2Cw].mp4.npy (1025, 1268)
# Golden Slumbers (Remastered 2009) [AcQjM7gV6mI].mp4.npy (1025, 1273)
# Glass Onion (Remastered 2009) [2tSIZLuCKUI].mp4.npy (1025, 1283)
# Get Back (Remastered 2009) [IKJqecxswCA].mp4.npy (1025, 1269)
# For You Blue (Remastered 2009) [TIFHRaZERHg].mp4.npy (1025, 1154)
# Everybody's Got Something To Hide Except Me And My Monkey (Remastered 2009) [eyV3zCq1OHM].mp4.npy (1025, 1273)
# Honey Pie (Remastered 2009) [0Sr0efOe8yk].mp4.npy (1025, 1274)
# Hey Bulldog (Remastered 2009) [g6DVE305g0s].mp4.npy (1025, 1273)
# Here Comes The Sun (Remastered 2009) [xUNqsfFUwhY].mp4.npy (1025, 1269)
# Her Majesty (Remastered 2009) [Mh1hKt5kQ_4].mp4.npy (1025, 977)
# Helter Skelter (Remastered 2009) [vWW2SzoAXMo].mp4.npy (1025, 1274)
# Happiness Is A Warm Gun (Remastered 2009) [vdvnOH060Qg].mp4.npy (1025, 1275)
# It's All Too Much (Remastered 2009) [2zc3idF_IZ0].mp4.npy (1025, 1271)
# I Will (Remastered 2009) [p-abNGP1BK4].mp4.npy (1025, 1266)
# I'm So Tired (Remastered 2009) [7cqHtGb9WYM].mp4.npy (1025, 1276)
# I've Got A Feeling (Remastered 2009) [DbKPZd5oihc].mp4.npy (1025, 1272)
# I Want You (She's So Heavy) (Remastered 2009) [tAe2Q_LhY8g].mp4.npy (1025, 1273)
# I Me Mine (Remastered 2009) [seqaTuXkqFI].mp4.npy (1025, 1273)
# Martha My Dear (Remastered 2009) [RXawa90YU2s].mp4.npy (1025, 1274)
# March Of The Meanies (Remastered 2009) [z2q5ailjVbA].mp4.npy (1025, 1270)
# Maggie Mae (Remastered 2009) [tSn1r9--tq4].mp4.npy (1025, 1283)
# Long, Long, Long (Remastered 2009) [e9vUCdfwlgw].mp4.npy (1025, 1273)
# Let It Be (Remastered 2009) [QDYfEBY9NM4].mp4.npy (1025, 1288)
# Julia (Remastered 2009) [TZip_br_v3w].mp4.npy (1025, 1265)
# Oh! Darling (Remastered 2009) [9BznFjbcBVs].mp4.npy (1025, 1268)
# Octopus's Garden (Remastered 2009) [De1LCQvbqV4].mp4.npy (1025, 1271)
# Ob-La-Di, Ob-La-Da (Remastered 2009) [_J9NpHKrKMw].mp4.npy (1025, 1286)
# Mother Nature's Son (Remastered 2009) [TMMiXjwhODU].mp4.npy (1025, 1269)
# Mean Mr Mustard (Remastered 2009) [oMarHac3VpQ].mp4.npy (1025, 1289)
# Maxwell's Silver Hammer (Remastered 2009) [mJag19WoAe0].mp4.npy (1025, 1272)
# Polythene Pam (Remastered 2009) [Cb0dTdTeHMU].mp4.npy (1025, 1289)
# Piggies (Remastered 2009) [RhY1x8CpWeI].mp4.npy (1025, 1288)
# Pepperland Laid Waste (Remastered 2009) [JGauvWfU-eY].mp4.npy (1025, 1221)
# Pepperland (Remastered 2009) [BXTKH1Pti34].mp4.npy (1025, 1271)
# Only A Northern Song (Remastered 2009) [vcvd-L73Cqs].mp4.npy (1025, 1272)
# One After 909 (Remastered 2009) [t8UeWjynWvE].mp4.npy (1025, 1272)
# Sea Of Holes (Remastered 2009) [t7Rn_tUs5oU].mp4.npy (1025, 1270)
# Savoy Truffle (Remastered 2009) [z9EaBjFvQpc].mp4.npy (1025, 1273)
# Rocky Raccoon (Remastered 2009) [sDcDCZGcZj8].mp4.npy (1025, 1282)
# Revolution 9 (Remastered 2009) [SNdcFPjGsm8].mp4.npy (1025, 1286)
# Revolution 1 (Remastered 2009) [OmsXsIv2Ppw].mp4.npy (1025, 1270)
# Sun King (Remastered 2009) [6bNMxWGHlTI].mp4.npy (1025, 1288)
# Something (Remastered 2009) [VWO3nEuWo4k].mp4.npy (1025, 1272)
# She Came In Through The Bathroom Window (Remastered 2009) [NVv7IzEVf3M].mp4.npy (1025, 1289)
# Sexy Sadie (Remastered 2009) [tSk5U4oHhu0].mp4.npy (1025, 1281)
# Sea Of Time (Remastered 2009) [PACDEO3Bhdk].mp4.npy (1025, 1205)
# Sea Of Monsters (Remastered 2009) [deIgt6r0ivA].mp4.npy (1025, 1274)
# Why Don't We Do It In The Road？ (Remastered 2009) [p4E6KtQg_z0].mp4.npy (1025, 1287)
# While My Guitar Gently Weeps (Remastered 2009) [bI8P6ZSHSvE].mp4.npy (1025, 1288)
# The End (Remastered 2009) [12R4FzIhdoQ].mp4.npy (1025, 1289)
# The Long And Winding Road (Remastered 2009) [fR4HjTH_fTM].mp4.npy (1025, 1271)
# Two Of Us (Remastered 2009) [cLQox8e9688].mp4.npy (1025, 1245)
# The Continuing Story Of Bungalow Bill (Remastered 2009) [J39DC9t0I5o].mp4.npy (1025, 1288)
# You Never Give Me Your Money (Remastered 2009) [BpndGZ71yww].mp4.npy (1025, 1273)
# Yer Blues (Remastered 2009) [HEQQ-1rd4A0].mp4.npy (1025, 1284)
# Yellow Submarine In Pepperland (Remastered 2009) [YnqH_tgPS5s].mp4.npy (1025, 1271)
# Yellow Submarine (Remastered 2009) [ztHxu-13UqI].mp4.npy (1025, 1244)
# Wild Honey Pie (Remastered 2009) [l-ekNlk5VDM].mp4.npy (1025, 1287)
# 04 The Beatles - Love You To.flac.npy (1025, 1271)
# 07 The Beatles - Kansas City Hey-Hey-Hey-Hey!.flac.npy (1025, 1284)
# 06 The Beatles - Mr. Moonlight.flac.npy (1025, 1280)
# 03 The Beatles - Paperback Writer.flac.npy (1025, 1275)
# 01 The Beatles - A Hard Day_s Night.flac.npy (1025, 1250)
# 05 The Beatles - Your Mother Should Know.flac.npy (1025, 1271)
# 06 The Beatles - Yellow Submarine.flac.npy (1025, 1287)
# 01 The Beatles - Love Me Do [Single Version].flac.npy (1025, 1242)
# 01 The Beatles - I Saw Her Standing There.flac.npy (1025, 1249)
# 05 The Beatles - Another Girl.flac.npy (1025, 1284)
# 04 The Beatles - Don_t Bother Me.flac.npy (1025, 1276)
# 02 The Beatles - The Night Before.flac.npy (1025, 1284)
# 03 The Beatles - If I Fell.flac.npy (1025, 1284)
# 04 The Beatles - Blue Jay Way.flac.npy (1025, 1222)
# 06 The Beatles - Till There Was You.flac.npy (1025, 1275)
# 05 The Beatles - Little Child.flac.npy (1025, 1274)
# 06 The Beatles - The Inner Light.flac.npy (1025, 1235)
# 03 The Beatles - Thank You Girl.flac.npy (1025, 1269)
# 06 The Beatles - I Want To Hold Your Hand.flac.npy (1025, 1277)
# 02 The Beatles - Norwegian Wood (This Bird Has Flown).flac.npy (1025, 1278)
# 02 The Beatles - The Fool On The Hill.flac.npy (1025, 1283)
# 03 The Beatles - Lucy In The Sky With Diamonds.flac.npy (1025, 1270)
# 03 The Beatles - I_m Only Sleeping.flac.npy (1025, 1286)
# 05 The Beatles - I_ll Follow The Sun.flac.npy (1025, 1284)
# 01 The Beatles - Magical Mystery Tour.flac.npy (1025, 1247)
# 07 The Beatles - Hello Goodbye.flac.npy (1025, 1286)
# 03 The Beatles - You Won_t See Me.flac.npy (1025, 1285)
# 06 The Beatles - Tell Me Why.flac.npy (1025, 1286)
# 01 The Beatles - Taxman.flac.npy (1025, 1236)
# 06 The Beatles - The Word.flac.npy (1025, 1284)
# 02 The Beatles - From Me To You.flac.npy (1025, 1273)
# 07 The Beatles - Hey Jude.flac.npy (1025, 1273)
# 05 The Beatles - I_ll Get You.flac.npy (1025, 1277)
# 04 The Beatles - She Loves You.flac.npy (1025, 1275)
# 03 The Beatles - All My Loving.flac.npy (1025, 1278)
# 01 The Beatles - It Won_t Be Long.flac.npy (1025, 1250)
# 01 The Beatles - Sgt. Pepper_s Lonely Hearts Club Band.flac.npy (1025, 1192)
# 02 The Beatles - Eleanor Rigby.flac.npy (1025, 1282)
# 04 The Beatles - I_m Happy Just To Dance With You.flac.npy (1025, 1286)
# 05 The Beatles - Here, There And Everywhere.flac.npy (1025, 1272)
# 03 The Beatles - You_ve Got To Hide Your Love Away.flac.npy (1025, 1284)
# 05 The Beatles - Boys.flac.npy (1025, 1277)
# 04 The Beatles - Getting Better.flac.npy (1025, 1286)
# 07 The Beatles - Can_t Buy Me Love.flac.npy (1025, 1284)
# 01 The Beatles - Drive My Car.flac.npy (1025, 1246)
# 02 The Beatles - All I_ve Got To Do.flac.npy (1025, 1277)
# 05 The Beatles - Think For Yourself.flac.npy (1025, 1280)
# 07 The Beatles - Please Mister Postman.flac.npy (1025, 1278)
# 02 The Beatles - Misery.flac.npy (1025, 1277)
# 07 The Beatles - Being For The Benefit Of Mr. Kite!.flac.npy (1025, 1284)
# 02 The Beatles - I_m A Loser.flac.npy (1025, 1285)
# 03 The Beatles - Flying.flac.npy (1025, 1286)
# 06 The Beatles - Ask Me Why.flac.npy (1025, 1276)
# 02 The Beatles - I Should Have Known Better.flac.npy (1025, 1286)
# 01 The Beatles - Help!.flac.npy (1025, 1247)
# 05 The Beatles - And I Love Her.flac.npy (1025, 1283)
# 04 The Beatles - Nowhere Man.flac.npy (1025, 1283)
# 02 The Beatles - We Can Work It Out.flac.npy (1025, 1274)
# 05 The Beatles - Lady Madonna.flac.npy (1025, 1275)
# 05 The Beatles - Fixing A Hole.flac.npy (1025, 1279)
# 07 The Beatles - Please Please Me.flac.npy (1025, 1277)
# 06 The Beatles - I Am The Walrus.flac.npy (1025, 1285)
# 02 The Beatles - With A Little Help From My Friends.flac.npy (1025, 1292)
# 04 The Beatles - Rock And Roll Music.flac.npy (1025, 1284)
# 04 The Beatles - I Need You.flac.npy (1025, 1283)
# 06 The Beatles - She_s Leaving Home.flac.npy (1025, 1281)
# 03 The Beatles - Anna.flac.npy (1025, 1277)
# 01 The Beatles - No Reply.flac.npy (1025, 1241)
# 06 The Beatles - You_re Going To Lose That Girl.flac.npy (1025, 1284)
# 07 The Beatles - Michelle.flac.npy (1025, 1278)
# 04 The Beatles - Chains.flac.npy (1025, 1277)
# Please Mister Postman - The Beatles cover [QCTwUTyQYJs].mp4.npy (1025, 1237)
# Robert Gordon - Run For Your Life (The Beatles Cover) [sfkycayQ_OE].mp4.npy (1025, 1272)
# heather nova we can work it out [VUunSZkaVgU].mp4.npy (1025, 1279)
# Tony Williams - Blackbird [Mirjk3qXUxg].mp4.npy (1025, 1266)
# Los Lobos - Tomorrow Never Knows (A Beatles Songbook, 1993) [ei2i1NelYV0].mp4.npy (1025, 1289)
# Humble Pie-Drive My Car (The Beatles cover) [zXBG73TnEZQ].mp4.npy (1025, 1282)
# Bette Midler In My Life Official Video [x6052dI9jRk].mp4.npy (1025, 1281)
# Judy Collins - When I'm Sixty-Four [yRUUWyXBfCw].mp4.npy (1025, 1267)
# Ringo Starr - Don't Pass Me By (live 2005) HQ 0815007 [IMQSTpxH9yI].mp4.npy (1025, 1291)
# And Your Bird Can Sing by Jim Reid (Beatles Cover) [9-3wcOp6qn8].mp4.npy (1025, 1284)
# Elliott Smith - I Me Mine (Beatles Cover) [se4ngK0obFU].mp4.npy (1025, 1286)
# Savoy Truffle - They Might Be Giants [KnB7ONSX3B8].mp4.npy (1025, 1286)
# Billy Joel - I'll Cry Instead (The Beatles Cover) [9LeePEK5NQI].mp4.npy (1025, 1267)
# Al Green   I want to hold your hand [xs9mkVMv830].mp4.npy (1025, 1263)
# Sweet - Paperback Writer (BBC Session) [nDqOr6NTqOY].mp4.npy (1025, 1268)
# The Hollies - A Taste Of Honey [iuxRCE8D74Q].mp4.npy (1025, 1291)
# I Want To Hold Your Hand - The Beatles ｜ Cover by The Iveys [4PoPxcwi3uw].mp4.npy (1025, 1244)
# I Am The Walrus - Spooky Tooth - HQ [i8RthS9cF0c].mp4.npy (1025, 1266)
# Wet Wet Wet - I Feel Fine - Lennon： A Tribute [QsCvMWviBQw].mp4.npy (1025, 1291)
# Del Shannon - From Me To You [Dfl9BUOuwBE].mp4.npy (1025, 1244)
# Let it be - Ray Charles [eof2c5fTcI8].mp4.npy (1025, 1276)
# David Bowie- Penny Lane [iHb3GIQGoIM].mp4.npy (1025, 1285)
# Robin Williams & Bobby McFerrin - Come Together (George Martin： In My Life CD) [j6VbspP47oY].mp4.npy (1025, 1236)
# Carlos Santana - Whit A Little Help From my Friends [edM1sy-b2_0].mp4.npy (1025, 1210)
# Sacred Rite ＂Eleanor Rigby (Beatles Cover)＂ Album： Is Nothing Sacred [mVKOcWia8_k].mp4.npy (1025, 1202)
# Procol Harum - Eight Days a Week (The Beatles cover) [VCCmqvAc6Kw].mp4.npy (1025, 1033)
# Ralph Towner - Here, There and Everywhere [nSGYWHE3Buo].mp4.npy (1025, 1249)
# Ringo Starr playing with The Beach Boys July 4th 1984 1 [kINQXKLm334].mp4.npy (1025, 1292)
# Stereophonics - Revolution (Beatles Cover) [CALV9lR_yIw].mp4.npy (1025, 1116)
# Brenda Lee Can't Buy Me Love [V1NO738X1i8].mp4.npy (1025, 1237)
# Aretha Franklin - The Fool On The Hill (This Girl's In Love With You Outtake) [zRnhGRLL9CI].mp4.npy (1025, 1278)
# Noel Gallagher Strawberry Fields Forever 2006 [jCp6xtokA28].mp4.npy (1025, 1252)
# Across The Universe - I'm The Walrus - Bus Scene - Bono [-etbkqh2ar4].mp4.npy (1025, 1284)
# Kip Winger - Drive My Car [AOa2VulaQsM].mp4.npy (1025, 1272)
# Judy Collins - Penny Lane [kvmtpV5L6KQ].mp4.npy (1025, 1266)
# Ike and Tina Turner - She came in through the Bathroom Window [2j-8aLvs5jk].mp4.npy (1025, 1286)
# The Bangles - ＂All Together Now＂ Beatles [0Qm358hRsG0].mp4.npy (1025, 1283)
# St Vincent - Dig A Pony - Live @ All Points West Festival 8⧸1⧸09 in HD [lan-UQfN0zs].mp4.npy (1025, 1292)
# Ella Fitzgerald Savoy Truffle [9KmvANzwRWk].mp4.npy (1025, 1270)
# Ted Nugent   I Want To Tell You [j86yydt9MtY].mp4.npy (1025, 1275)
# Stefanie Hempel ALL THINGS MUST PASS [hhQ3hSPZLDk].mp4.npy (1025, 1247)
# Tori Amos - Happiness Is A Warm Gun + Lyrics [MeXCWM_gssY].mp4.npy (1025, 1276)
# Oasis - I am the Walrus (live, Berlin 2002) [TxbVdqm6iaE].mp4.npy (1025, 1291)
# Hold Me Tight by Stackridge [sM_Xsa5NCxA].mp4.npy (1025, 1290)
# LOS FABULOSOS CADILLACS - TWIST Y GRITOS - VIVO -  1989 [nuuyOAy-TBo].mp4.npy (1025, 1290)
# Frank Zappa Beatles medley - Cleveland 5th March 1988 [_kna4NiU-eM].mp4.npy (1025, 1290)
# The Four Seasons - We Can Work It Out (Beatles Cover) [aT3Ee-BwsUo].mp4.npy (1025, 1282)
# Status Quo - Getting Better [gPGpniZ6XR8].mp4.npy (1025, 1275)
# House of Heroes- Can't Buy Me Love [GROO76xg7zU].mp4.npy (1025, 1278)
# Herb Alpert & The Tijuana Brass - A Taste of Honey [hfcORALgXGg].mp4.npy (1025, 1221)
# KGB - I've Got a Feeling [jtHCtR02cjo].mp4.npy (1025, 1267)
# U2 - Rain (Beatles Cover) Live [CtatjOMPDwU].mp4.npy (1025, 1187)
# Ike & Tina Turner - She Came in Through the Bathroom Window - Get Back - Proud Mary, 1971 [yx0hY2NJNVA].mp4.npy (1025, 1290)
# Amy Winehouse - All my lovin' (The Beatles's cover) [9FiQnrRT16s].mp4.npy (1025, 1219)
# Joe Cocker - ＂She Came In Through The Bathroom Window＂ 1970 ⧸w Leon Russell [Z8IvCyw_aTQ].mp4.npy (1025, 1259)
# something Bob dylan cover Beatles [AGm4a8isL50].mp4.npy (1025, 1287)
# Johnny Rivers Run For Your Life [I6xxKCEFun0].mp4.npy (1025, 1271)
# Boney M - Two Of Us (1979) [PrpGci0SjFg].mp4.npy (1025, 1288)
# Beach Boys- You've got to hide your love away [EdsT_4vafk0].mp4.npy (1025, 1282)
# The Brothers Johnson - Come Together [nRCdnASv9cE].mp4.npy (1025, 1223)
# Hollyridge Strings - If I Fell [-WLtqaYbYq0].mp4.npy (1025, 1288)
# Across the Universe - Being for the Benefit of Mr. Kite! [59ahx9ckqIw].mp4.npy (1025, 1284)
# LOWELL FULSON'S WHY DON'T WE DO IT IN THE ROAD [hxULdSG5VPw].mp4.npy (1025, 1265)
# Roy Wood - Lovely Rita and Polythene Pam [h5xbhu7mErg].mp4.npy (1025, 1272)
# The Libertines - A Day In The Life [zA3CpQs9wPs].mp4.npy (1025, 1270)
# CHER ＂THE LONG AND WINDING ROAD＂ (1973) STUDIO RECORDING [nziq7ZkqSeE].mp4.npy (1025, 1270)
# Joe Jackson covers John Lennon's Girl (live 2010) HD [cVJ8tKvpmE4].mp4.npy (1025, 1277)
# The Supremes- Yesterday [QQICzRANMfw].mp4.npy (1025, 1263)
# While My Guitar Gently Weeps - Nigel Kennedy [OMoMNF9_SoA].mp4.npy (1025, 1274)
# Fool on the Hill - Maggie Bell [SVVF4QOQfK4].mp4.npy (1025, 1253)
# Tina Turner - Come Together (1970) STUDIO VERSION [yqAkdxjneig].mp4.npy (1025, 1266)
# Peggy Lee - A hard days night [mUBAGLinKfI].mp4.npy (1025, 1275)
# SONNY & CHER  ＂Got To Get You Into My Life' [iNFZjBPjKJM].mp4.npy (1025, 1292)
# The Sandpipers Michelle [c-A8O0JndoA].mp4.npy (1025, 1282)
# Chris Farlowe - ＂Yesterday＂ (1966) [rM5M0GMZOXk].mp4.npy (1025, 1082)
# Let it be, performed by Nick Cave [MjEJxr538ZA].mp4.npy (1025, 1255)
# Oasis-Within You Without You [CoNNZlRYX2M].mp4.npy (1025, 1274)
# Dalida - Amo ( Beatles - Girl ) [h78ufQsH-SE].mp4.npy (1025, 1266)
# Natalie Cole - Lucy in the Sky with Diamonds - The Natalie Cole Special 1978 [9KD6tCdE9Qo].mp4.npy (1025, 1288)
# Soundgarden-Everybody's Got Something to Hide Except for Me and My Monkey (Beatles Cover) [L_dnIx-f2fE].mp4.npy (1025, 1258)
# Tell Me Why - Beach Boys [lkn89Z2m6J4].mp4.npy (1025, 1280)
# The Fray - Fixing A Hole (Beatles Cover) [RL4RFBsfjTk].mp4.npy (1025, 1201)
# Lady Gaga： Imagine [uQRuYS_h-Vs].mp4.npy (1025, 1267)
# The Baby Boomers Can't Buy Me Love [chppFJ43tUA].mp4.npy (1025, 1283)
# The Jam - And Your Bird Can Sing [otgFDGdykUs].mp4.npy (1025, 1265)
# Nanci Griffith - Things We Said Today [gNu0HrF6k78].mp4.npy (1025, 1289)
# Jimmy Page & Yes - I'm Down (Beatles cover) [j90CnFv3rtY].mp4.npy (1025, 1099)
# Bon Jovi - With A Little Help From My Friends [7zpjt4vjrjY].mp4.npy (1025, 1289)
# Sonic Youth- Within You Without You (Beatles cover) [JwoMjnoXn3E].mp4.npy (1025, 1101)
# The Fevers - Balada de John e Yoko (The Ballad of John and Yoko) [JeGYhwBmTO0].mp4.npy (1025, 1267)
# Ween - She Said, She Said [bIaOpeezDnM].mp4.npy (1025, 1286)
# Phil Collins - Golden Slumbers, Carry That Weight, The End (1998) [SgoQ1gi_7i0].mp4.npy (1025, 1253)
# Dana Fuchs- Why Don't We Do It In The Road [36ld2-zzQIg].mp4.npy (1025, 1278)
# Joe Jackson & Todd Rundgren - While My Guitar Gently Weeps [mQxVkf3fRIM].mp4.npy (1025, 1285)
# The Pixies Wild Honey Pie (Beatles cover) [LyVsg4nwJn0].mp4.npy (1025, 1277)
# Laibach - Across the Universe [_q5mlb3Bjzs].mp4.npy (1025, 1235)
# Deep Purple - Help (Beatles Cover) Denmark 1968 HD [WBugcmKpO2o].mp4.npy (1025, 1291)
# Elvis Costello performs ＂Penny Lane＂ at the Gershwin Prize for Paul McCartney [HVcfPzoXWnY].mp4.npy (1025, 1290)
# Magic Numbers - She´s Leaving Home (Beatles Cover) [OJxaKGkjqxg].mp4.npy (1025, 1127)
# 10CC - Paperback Writer [AiHmMEUK5EQ].mp4.npy (1025, 1073)
# Across the universe - David Bowie [BIkYfhXG0ho].mp4.npy (1025, 1250)
# ＂Eleanor Rigby ⧸ I Want You (She's So Heavy)＂ Soulive - Live at Brooklyn Bowl [04kJr6taFz0].mp4.npy (1025, 1272)
# Kylie Minogue - Help (John Lennon Tribute Concert 1990) [aqOluhXOzWs].mp4.npy (1025, 1291)
# ＂I Call Your Name＂ The Mamas & the Papas [X_WlLYBfL-k].mp4.npy (1025, 1276)
# Junior Parker - Taxman [byjPd28KegM].mp4.npy (1025, 1247)
# Johnny Cash- In My Life [2S9Hjw4o8f8].mp4.npy (1025, 1269)
# The inmates - Day Tripper (stereo) [f9ZYj2aiv40].mp4.npy (1025, 1287)
# Golden Slumbers (Lyrics) - [QcZjoHhuL6M].mp4.npy (1025, 1292)
# I Should Have Known Better - Beach Boys [rImXm268AO8].mp4.npy (1025, 1270)
# Celine Dion ＂Because＂ (Beatles Cover) [BVaNR0NOTik].mp4.npy (1025, 1165)
# Arctic Monkeys - All My Loving (Beatles cover) live @ Madison Square Garden ⧸ New York NY [oRk6fGAkaZI].mp4.npy (1025, 1287)
# Revolution (The Beatles Cover) - Stone Temple Pilots [Kq9r61ZHJds].mp4.npy (1025, 1197)
# Mando Diao A Hard Days Night [ukZJJHslm40].mp4.npy (1025, 1257)
# Stevie Ray Vaughan & Double Trouble - Taxman [djPRz4rnm8I].mp4.npy (1025, 1274)
# Dionne Warwick - Hey Jude [e_f5v5do3Sc].mp4.npy (1025, 1203)
# The Tubes -- I Saw Her Standing There   (Live at Shepherds Bush Empire 2004) [oIX_5e0r-WE].mp4.npy (1025, 1291)
# Paperback Writer - The Octopussy's Garden and Its Freaky Animals [UaiAQo6J3ik].mp4.npy (1025, 1281)
# The Residents - Flying [C-xxXN9qAQI].mp4.npy (1025, 1112)
# U2 - Happiness Is A Warm Gun (The Gun Mix) [wTNefEWOTNk].mp4.npy (1025, 1271)
# ＂Paperback Writer＂ - The Strangers (1965) [CCWmbxoK5mA].mp4.npy (1025, 1236)
# Green Day Working Class Hero (Uncensored version) [6VsCKbcSNZ8].mp4.npy (1025, 1266)
# Chick Corea & Gary Burton - Eleanor Rigby [bxfi0g_5CiM].mp4.npy (1025, 1079)
# Meat Loaf - Why Don't We Do It in the Road -  with CC Coletti and Patti Russo Dallas, TX. [ku3Sf5QhE5w].mp4.npy (1025, 1288)
# P.J. Proby · That Means A Lot (1965) [V6-26dnHARI].mp4.npy (1025, 1289)
# Jeff Beck - A day in the life (Beatles) [toMTAHsz26I].mp4.npy (1025, 1291)
# The Kennedys - A Day In The Life - 27th Annual John Lennon Tribute [ZQZNPycVux4].mp4.npy (1025, 924)
# Vince Guaraldi & Bola Sete - I'm A Loser (Beatles cover, 1966) [EbzcivVQEGw].mp4.npy (1025, 1286)
# nick cave： here comes the sun [FLCy_sycPJo].mp4.npy (1025, 1260)
# Marianne Faithfull - ＂Working Class Hero＂ (live) [3N_rNz2oAGA].mp4.npy (1025, 1281)
# Arctic Monkeys - Come Together (Beatles Cover) [PcQQHVqcmn4].mp4.npy (1025, 1276)
# Esther Ofarim - She´s leaving home [6btj6uX9qu8].mp4.npy (1025, 1276)
# Rain - Humble Pie [N-AKEuMrZuI].mp4.npy (1025, 1267)
# Let It Be - The Ventures.wmv [Q-hcweWXbYo].mp4.npy (1025, 865)
# Nina Simone： Here Comes The Sun [fjIuXsDcc2E].mp4.npy (1025, 1292)
# Melissa Etheridge, etc. - Drive My Car (Beatles Cover) [i2WuKU8LuUY].mp4.npy (1025, 1290)
# Green Day - Hey Jude, TRIESTE (Italy) 2013 (1st row!) [Ll7UGhHTerM].mp4.npy (1025, 1290)
# BECK - I've Got A Feeling [WVqDBdpExlk].mp4.npy (1025, 1291)
# echo & the bunnymen ⧸ all you need is love [bKukSnSZfgU].mp4.npy (1025, 1264)
# Alice Cooper ft. Johnny Depp - ＂Revolution＂ (Beatles cover) - Live at Orpheum [bADuQ-Z33uc].mp4.npy (1025, 1283)
# Marianne Faithfull - Yesterday [x8t5bDg4Eh0].mp4.npy (1025, 1282)
# Link Wray & The Raymen - Please Please Me [jWJoIgHUAa0].mp4.npy (1025, 1266)
# Leslie West - I Feel Fine.wmv [PVlz7aiXUt0].mp4.npy (1025, 1276)
# Frank Sinatra - Something (Beatles cover written by George Harrison) [FoDyoW5IAwk].mp4.npy (1025, 1291)
# Ike & Tina Turner - Get Back 1973 [Sr9uCJX4IpA].mp4.npy (1025, 1289)
# Suzi Quatro - I Wanna Be Your Man (Beatles cover) [_1I3uH1iM0g].mp4.npy (1025, 1262)
# Elton John - Lucy in the Sky with Diamonds [JZN9bCEGntg].mp4.npy (1025, 1286)
# Stereophonics with Oasis - I'm Only Sleeping [L8Ke4xja7xw].mp4.npy (1025, 1291)
# The Shadows ＂Paperback Writer＂ [9E35SUliHgU].mp4.npy (1025, 1276)
# Jeff Lynne - With A Little Help From My Friends ⧸ Nowhere Man [GTvSt4qrS1E].mp4.npy (1025, 1268)
# Bryan Ferry - She's Leaving Home [RKGHu3Wq2JQ].mp4.npy (1025, 1273)
# Leningrad Cowboys Back in USSR N [RVUr28-L9sw].mp4.npy (1025, 1284)
# I Want You (She's So Heavy) - Soundgarden 17 Oberhausen 1995 [PcQqW5SGZHg].mp4.npy (1025, 1289)
# The Beatles - Revolution 9 - Acoustic Cover - Danny McEvoy, Jazzy and Ellie. [UxXA2_tRVi0].mp4.npy (1025, 1288)
# I Feel Fine - The Ventures [TCEB1qkhC9Y].mp4.npy (1025, 1278)
# JAMES TAYLOR  -  Here comes  the sun ( by George Harrison) [p0hHjB7xshE].mp4.npy (1025, 1290)
# Al Jarreau - She's leaving home [iinIIW-TM_4].mp4.npy (1025, 1254)
# Emmylou Harris - For No One [NIy2Lz_Evio].mp4.npy (1025, 1290)
# Siouxsie & The Banshees - Helter Skelter [szPQCvJ8MPg].mp4.npy (1025, 1286)
# Sheryl Crow - Mother Nature's Son [v9F4LsPUNU8].mp4.npy (1025, 1280)
# Bon Jovi  - Imagine ⧸ Give peace a chance (live) - 02-09-95 [lFYRymywIhE].mp4.npy (1025, 1287)
# The Who ＂I Saw Her Standing There＂ [47x6HNygt5o].mp4.npy (1025, 1259)
# Stereophonics - Sgt. Pepper´s [Reprise] (Beatles Cover) [pEQSX48MEDw].mp4.npy (1025, 1200)
# Chet Baker -  a taste of honey [nnTHJucUdzQ].mp4.npy (1025, 1282)
# Strawberry Fields Forever (Across The Universe) [xLiID6qFIsI].mp4.npy (1025, 1259)
# Fats Domino - Lovely Rita.wmv [NEbDR7KXr7c].mp4.npy (1025, 1171)
# the B-52's Paperback Writer - The Beatles cover [qCdHW9tULHM].mp4.npy (1025, 1284)
# Count Basie  & His Orchestra - Can't Buy Me Love [7vRI2jlXkHI].mp4.npy (1025, 1259)
# The Supremes - Can´t Buy Me Love [GLwZ17mrOM8].mp4.npy (1025, 1270)
# Norwegian Wood- Jan & Dean [N03RUqh5pnY].mp4.npy (1025, 1281)
# Alison Krauss - I Will (Live) [3989jHX3sMQ].mp4.npy (1025, 1281)
# The Beatles Long, Long, Long [3ExbOPPP0fA].mp4.npy (1025, 1280)
# Pearl Jam - I've Got A Feeling [iSqugzxhgpU].mp4.npy (1025, 1261)
# The Seekers Yesterday Album Version 1966 [Mlcmcb7Oi5g].mp4.npy (1025, 1238)
# Katja Ebstein - A Hard Days Night [tD7vFn33ul8].mp4.npy (1025, 1278)
# Joe Cocker - Let It Be [Mzf5EBY8gCQ].mp4.npy (1025, 1250)
# Oasis - You've Got To Hide Your Love Away [YTsDs4K5Kkk].mp4.npy (1025, 1211)
# Bee Gees & Peter Frampton - Polythene Pam, She Came In Through The Bathroom Window, Nowhere Man [Od-DKDi8sy0].mp4.npy (1025, 1286)
# Hardin & York - Northern Medley [XSKJap9wydA].mp4.npy (1025, 1288)
# Eddie Murphy - Good Day Sunshine [jTc6YGn5zU0].mp4.npy (1025, 1246)
# Annie Lennox - Don't let me down (Live) [71wxc3TQ73Q].mp4.npy (1025, 1229)
# Deep purple we can work it out UZ8pywYaI].mp4.npy (1025, 1265)
# Chris Cornell live ' A Day In The Life' at The Moore Theater 2011 [7Qm1J3n114o].mp4.npy (1025, 1287)
# Kaiser Chiefs - Getting Better (Beatles Cover) [nCcU2xfvz0o].mp4.npy (1025, 1185)
# 801 - Tomorrow Never Knows [UkGXUn0Kuuw].mp4.npy (1025, 1277)
# Otis Redding - Day Tripper (HQ) [7nUGmo71SfE].mp4.npy (1025, 1277)
# Rosanne Cash I Don't Want To Spoil The Party [_fjsQPS5l-w].mp4.npy (1025, 1278)
# Lynsey De Paul - Because [eILepvfCREg].mp4.npy (1025, 1277)
# Billy J Kramer - Do You Want to Know a Secret [lDCkdaSs_vg].mp4.npy (1025, 1285)
# Mary McCaslin - Things we said today [CJW69RFXTgY].mp4.npy (1025, 1268)
# Art Garfunkel - I Will (Across America) [wpOhJEJknes].mp4.npy (1025, 1288)
# Aretha Franklin ＂Let It Be＂ [2UoTvwfo_rU].mp4.npy (1025, 1279)
# The Skatalites - Ringo's Theme (aka This Boy) Version 2 [oC-0NdVQ9FI].mp4.npy (1025, 1272)
# Greatest Rock Guitar Playing： Duane Allman on Wilson Pickett's ＂Hey Jude＂ [B5B1Vfdk7W8].mp4.npy (1025, 1262)
# Flamin' Groovies - And Your Bird Can Sing - 1981 [txXTO0o0ZK0].mp4.npy (1025, 1285)
# Jaco Pastorius - BlackBird (Studio Version) [Zd6DTRywF7Q].mp4.npy (1025, 1261)
# 10cc Across the Universe 1993 [haOMzYtARHE].mp4.npy (1025, 1201)
# Marianne Faithfull - I'm a loser [xaqU82fOi6k].mp4.npy (1025, 1220)
# I'm A Loser - Eels [wBwwF8isyPc].mp4.npy (1025, 1254)
# The Jam - Slow Down [WTQ76fuv0y8].mp4.npy (1025, 1277)
# Linda Ronstadt  -  ＂Good Night＂  (Beatles Cover) [_MWTMTp1R7k].mp4.npy (1025, 1267)
# Sexy Sadie - Beatles cover by Paul Weller [1XMwilXdi-I].mp4.npy (1025, 1271)
# Sarah Vaughan - ＂Fool on the Hill＂ [DTXDb4ksvsY].mp4.npy (1025, 1291)
# Cory Chisel and The Wandering Sons - Fixing A Hole (The Beatles) [KodtUnPuHsA].mp4.npy (1025, 1284)
# Joe Cocker ：：：：： I'll Cry Instead. [kxPla6zxA8k].mp4.npy (1025, 984)
# Youngblood (Cozy Powell) - 'The Continuing Story of Bungalow Bill' (1969) [kAkaahX9kdU].mp4.npy (1025, 1280)
# Rare Sonny and Cher Comedy Hour I'll Follow The Sun 1973 [-5f7gGdtNTw].mp4.npy (1025, 1292)
# Keith Moon In My Life [Ugm1C1jSLDQ].mp4.npy (1025, 1278)
# Jeff Beck - She's A Woman - live [4d38xOxzjZc].mp4.npy (1025, 1286)
# SAMMY DAVIS JR HEARIN IS BELIEVIN 5 [sBqn12H2Aws].mp4.npy (1025, 1288)
# A Hard Day's Night  Otis Redding [OO-SAflX0qI].mp4.npy (1025, 1273)
# The Swinging Blue Jeans - This Boy  (HQ Stereo) [M7JxEDm4HGM].mp4.npy (1025, 1288)
# Ozzy Osbourne w⧸ Slash - In my life ( Beatles cover ) [yOfl1Oqe_DA].mp4.npy (1025, 1269)
# I'm Down - Aerosmith (Lyrics) [npG_SQaohro].mp4.npy (1025, 1265)
# Eight Days a Week - The Runaways [0KOO0Gg1dJg].mp4.npy (1025, 1257)
# Badfinger - Come and get it 1970 [Bk57K4OGrAg].mp4.npy (1025, 1287)
# Tenacious D - MSG And Your Bird Can Sing (Beatles) [ePo7wvjYBe8].mp4.npy (1025, 1291)
# Bee Gees and Peter Frampton -I Want You [JHyDulGDnvw].mp4.npy (1025, 1286)

# %% [markdown]
# ##2.1 Usando STFTs
# Ideia menos inteligente, pela ordem de complexidade elevada da função :)

# %%
def load_and_fix_stft(filepath):
    """
    Carrega um arquivo .npy que contém STFT em formato (freq, time) ou (time, freq).
    Queremos padronizar para (time, 1025).
    """
    arr = np.load(filepath)

    # Se a primeira dimensão for 1025, significa que provavelmente está no formato (1025, frames).
    # Transpomos para ficar (frames, 1025).
    if arr.shape[0] == 1025:
        arr = arr.T  # Agora fica (frames, 1025)

    # Se mesmo assim a segunda dimensão não for 1025, avisamos e ignoramos.
    if arr.shape[1] != 1025:
        print(f"[Aviso] O arquivo '{filepath}' tem shape {arr.shape}, que não é (X, 1025). Será ignorado.")
        return None

    return arr

# Carrega e padroniza os STFTs das músicas originais
originals = {}
for f in os.listdir(dir_originals):
    if f.endswith('.npy'):
        filepath = os.path.join(dir_originals, f)
        arr = load_and_fix_stft(filepath)
        if arr is not None:
            originals[f] = arr

# Carrega e padroniza os STFTs dos covers
covers = {}
for f in os.listdir(dir_covers):
    if f.endswith('.npy'):
        filepath = os.path.join(dir_covers, f)
        arr = load_and_fix_stft(filepath)
        if arr is not None:
            covers[f] = arr

# Se ambos os dicionários estiverem preenchidos, calculamos o DTW
results = []
for orig_name, orig_stft in originals.items():
    for cover_name, cover_stft in covers.items():
        # Calcula DTW entre as matrizes (time, 1025) de cada música
        distance, _ = fastdtw(orig_stft, cover_stft, dist=euclidean)
        results.append({
            "Original": orig_name,
            "Cover": cover_name,
            "DTW_Distance": distance
        })

# Cria um DataFrame para exibir resultados
df_results = pd.DataFrame(results)

# Exibe (imprime) o DataFrame
print(df_results)

# Se você usar a ferramenta ace_tools:
#import ace_tools as tools
#tools.display_dataframe_to_user(name="Distâncias DTW entre Músicas", dataframe=df_results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-854618e3db18> in <cell line: 0>()
#      41     for cover_name, cover_stft in covers.items():
#      42         # Calcula DTW entre as matrizes (time, 1025) de cada música
# ---> 43         distance, _ = fastdtw(orig_stft, cover_stft, dist=euclidean)
#      44         results.append({
#      45             "Original": orig_name,
#
# fastdtw/_fastdtw.pyx in fastdtw._fastdtw.fastdtw()
#
# fastdtw/_fastdtw.pyx in fastdtw._fastdtw.__fastdtw()
#
# fastdtw/_fastdtw.pyx in fastdtw._fastdtw.__dtw()
#
# /usr/local/lib/python3.11/dist-packages/scipy/spatial/distance.py in euclidean(u, v, w)
#     482
#     483
# --> 484 def euclidean(u, v, w=None):
#     485     """
#     486     Computes the Euclidean distance between two 1-D arrays.
#
# KeyboardInterrupt:

# %% [markdown]
# ##2.2 Usando Cromas
# Diminui a complexidade em 1000x.

# %%
def stft_to_chroma(filepath, sr=44100, hop_length=512, n_fft=1024):
    """
    Lê um arquivo .npy contendo STFT e converte para cromagrama usando librosa.
    Formato de entrada esperado: (freq, tempo) ou (tempo, freq).
    Saída: cromagrama no formato (frames, 12).
    """
    # Carrega o STFT
    stft_data = np.load(filepath)  # Pode ser (freq, time) ou (time, freq)

    # Se a primeira dimensão for menor que a segunda, é provável que esteja (time, freq).
    # Precisamos de (freq, time) para passar a 'S=' no chroma_stft.
    if stft_data.shape[0] < stft_data.shape[1]:
        stft_data = stft_data.T  # Agora fica (freq, time)

    # Converte STFT em Cromagrama (12 bins)
    # 'S=' deve ser um espectrograma de magnitude não negativa.
    # Se você salvou stft_data já como magnitude (np.abs(STFT)), isso funciona diretamente.
    chroma = librosa.feature.chroma_stft(
        S=stft_data,   # passa o STFT (freq x frames)
        sr=sr,
        hop_length=hop_length,
        n_fft=n_fft,
        n_chroma=12
    )
    # chroma terá shape (12, frames)

    # Transpõe para (frames, 12), padrão que usaremos no DTW
    chroma = chroma.T  # (frames, 12)
    return chroma

# Carrega dicionários de cromagramas, convertendo "on the fly" a partir dos arquivos STFT
originals = {}
for f in os.listdir(dir_originals):
    if f.endswith('.npy'):
        filepath = os.path.join(dir_originals, f)
        c = stft_to_chroma(filepath)
        originals[f] = c

covers = {}
for f in os.listdir(dir_covers):
    if f.endswith('.npy'):
        filepath = os.path.join(dir_covers, f)
        c = stft_to_chroma(filepath)
        covers[f] = c

# DTW entre cada música original e cada cover (agora usando cromas!)
results = []
for orig_name, orig_chroma in originals.items():
    for cover_name, cover_chroma in covers.items():
        distance, _ = fastdtw(orig_chroma, cover_chroma, dist=euclidean)
        results.append({
            "Original": orig_name,
            "Cover": cover_name,
            "DTW_Distance": distance
        })

df_results = pd.DataFrame(results)
print(df_results)
# Out:
# /usr/local/lib/python3.11/dist-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
#                                  Original  \
# 0      07 The Beatles - This Boy.flac.npy
# 1      07 The Beatles - This Boy.flac.npy
# 2      07 The Beatles - This Boy.flac.npy
# 3      07 The Beatles - This Boy.flac.npy
# 4      07 The Beatles - This Boy.flac.npy
# ...                                   ...
# 47952    04 The Beatles - Chains.flac.npy
# 47953    04 The Beatles - Chains.flac.npy
# 47954    04 The Beatles - Chains.flac.npy
# 47955    04 The Beatles - Chains.flac.npy
# 47956    04 The Beatles - Chains.flac.npy
#
#                                                    Cover  DTW_Distance
# 0      Please Mister Postman - The Beatles cover [QCT...    168.165103
# 1      Robert Gordon - Run For Your Life (The Beatles...    244.102269
# 2      heather nova we can work it out [VUunSZkaVgU]....    177.162213
# 3        Tony Williams - Blackbird [Mirjk3qXUxg].mp4.npy    189.564241
# 4      Los Lobos - Tomorrow Never Knows (A Beatles So...    155.475902
# ...                                                  ...           ...
# 47952  I'm Down - Aerosmith (Lyrics) [npG_SQaohro].mp...    227.854655
# 47953  Eight Days a Week - The Runaways [0KOO0Gg1dJg]...    173.709501
# 47954  Badfinger - Come and get it 1970 [Bk57K4OGrAg]...    159.615348
# 47955  Tenacious D - MSG And Your Bird Can Sing (Beat...    163.084043
# 47956  Bee Gees and Peter Frampton -I Want You [JHyDu...    169.399918
#
# [47957 rows x 3 columns]

# %%
df_results.head(10)
# Out:
#                              Original  \
# 0  07 The Beatles - This Boy.flac.npy
# 1  07 The Beatles - This Boy.flac.npy
# 2  07 The Beatles - This Boy.flac.npy
# 3  07 The Beatles - This Boy.flac.npy
# 4  07 The Beatles - This Boy.flac.npy
# 5  07 The Beatles - This Boy.flac.npy
# 6  07 The Beatles - This Boy.flac.npy
# 7  07 The Beatles - This Boy.flac.npy
# 8  07 The Beatles - This Boy.flac.npy
# 9  07 The Beatles - This Boy.flac.npy
#
#                                                Cover  DTW_Distance
# 0  Please Mister Postman - The Beatles cover [QCT...    168.165103
# 1  Robert Gordon - Run For Your Life (The Beatles...    244.102269
# 2  heather nova we can work it out [VUunSZkaVgU]....    177.162213
# 3    Tony Williams - Blackbird [Mirjk3qXUxg].mp4.npy    189.564241
# 4  Los Lobos - Tomorrow Never Knows (A Beatles So...    155.475902
# 5  Humble Pie-Drive My Car (The Beatles cover) [z...    203.131866
# 6  Bette Midler In My Life Official Video [x6052d...    214.577019
# 7  Judy Collins - When I'm Sixty-Four [yRUUWyXBfC...    157.349484
# 8  Ringo Starr - Don't Pass Me By (live 2005) HQ ...    199.518330
# 9  And Your Bird Can Sing by Jim Reid (Beatles Co...    184.659368

# %% [markdown]
# ###2.2.1. Salvando em json

# %%
import json

# convertendo para json
data = df_results.to_dict(orient='records')

with open('df_results.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
# lendo do json
with open('df_results.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data)

print(df.head())
# Out:
#                              Original  \
# 0  07 The Beatles - This Boy.flac.npy
# 1  07 The Beatles - This Boy.flac.npy
# 2  07 The Beatles - This Boy.flac.npy
# 3  07 The Beatles - This Boy.flac.npy
# 4  07 The Beatles - This Boy.flac.npy
#
#                                                Cover  DTW_Distance
# 0  Please Mister Postman - The Beatles cover [QCT...    168.165103
# 1  Robert Gordon - Run For Your Life (The Beatles...    244.102269
# 2  heather nova we can work it out [VUunSZkaVgU]....    177.162213
# 3    Tony Williams - Blackbird [Mirjk3qXUxg].mp4.npy    189.564241
# 4  Los Lobos - Tomorrow Never Knows (A Beatles So...    155.475902

# %%
df
# Out:
#                                  Original  \
# 0      07 The Beatles - This Boy.flac.npy
# 1      07 The Beatles - This Boy.flac.npy
# 2      07 The Beatles - This Boy.flac.npy
# 3      07 The Beatles - This Boy.flac.npy
# 4      07 The Beatles - This Boy.flac.npy
# ...                                   ...
# 47952    04 The Beatles - Chains.flac.npy
# 47953    04 The Beatles - Chains.flac.npy
# 47954    04 The Beatles - Chains.flac.npy
# 47955    04 The Beatles - Chains.flac.npy
# 47956    04 The Beatles - Chains.flac.npy
#
#                                                    Cover  DTW_Distance
# 0      Please Mister Postman - The Beatles cover [QCT...    168.165103
# 1      Robert Gordon - Run For Your Life (The Beatles...    244.102269
# 2      heather nova we can work it out [VUunSZkaVgU]....    177.162213
# 3        Tony Williams - Blackbird [Mirjk3qXUxg].mp4.npy    189.564241
# 4      Los Lobos - Tomorrow Never Knows (A Beatles So...    155.475902
# ...                                                  ...           ...
# 47952  I'm Down - Aerosmith (Lyrics) [npG_SQaohro].mp...    227.854655
# 47953  Eight Days a Week - The Runaways [0KOO0Gg1dJg]...    173.709501
# 47954  Badfinger - Come and get it 1970 [Bk57K4OGrAg]...    159.615348
# 47955  Tenacious D - MSG And Your Bird Can Sing (Beat...    163.084043
# 47956  Bee Gees and Peter Frampton -I Want You [JHyDu...    169.399918
#
# [47957 rows x 3 columns]
